# %%
from textblob import TextBlob

quote1 = """It is a truth universally acknowledged, that a single man in possession of a good fortune, must be in want of a wife."""

quote2 = """Darcy, as well as Elizabeth, really loved them; and they were both ever sensible of the warmest gratitude towards the persons who, by bringing her into Derbyshire, had been the means of uniting them."""

sentiment1 = TextBlob(quote1).sentiment
sentiment2 = TextBlob(quote2).sentiment

print(quote1 + " has a sentiment of " + str(sentiment1))
print(quote2 + " has a sentiment of " + str(sentiment2))
# Out:
# It is a truth universally acknowledged, that a single man in possession of a good fortune, must be in want of a wife. has a sentiment of Sentiment(polarity=0.20952380952380953, subjectivity=0.27142857142857146)
# Darcy, as well as Elizabeth, really loved them; and they were both ever sensible of the warmest gratitude towards the persons who, by bringing her into Derbyshire, had been the means of uniting them. has a sentiment of Sentiment(polarity=0.7, subjectivity=0.8)

# %%
with open ('../../../predieandprej.txt', 'r') as f:
    book = f.read()

# %%
book_blob = TextBlob(book)

# %%
sentiments = 0
for sentence in book_blob.sentences:
    sentiments += sentence.sentiment.polarity
    # if sentence.sentiment.polarity == 1:
    #     print(sentence)

# %%
print(sentiments/len(book_blob.sentences))
# Out:
# 0.09868379660328527

# %%
word_counts = book_blob.word_counts
words = book_blob.words

# %%
len(words), sum(word_counts.values()), len(word_counts.keys())
# Out:
# (133821, 133821, 7335)

# %%
sorted_word_counts = sorted(word_counts.items(), key=lambda kv: kv[1], reverse=True)

# %%
import matplotlib.pyplot as plt

x,y = zip(*sorted_word_counts)
plt.bar(x[:10],y[:10])
# Out:
# <BarContainer object of 10 artists>
